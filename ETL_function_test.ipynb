# %%
import json
import pandas as pd
import numpy as np

import re

from sqlalchemy import create_engine
import psycopg2

# from config import db_password

import time

# 1. Create a function that takes in three arguments;
# Wikipedia data, Kaggle metadata, and MovieLens rating data (from Kaggle)
file_1 = 'wikipedia-movies.json'
file_2 = 'movies_metadata.csv'
file_3 = 'ratings.csv'

kaggle_metadata = pd.read_csv(f'archive/movies_metadata.csv', low_memory=False)
wiki_movies_df = pd.DataFrame(wiki_movies_raw)

def function_name():
    # 2. Read in the kaggle metadata and MovieLens ratings CSV files as Pandas DataFrames.
    

    # 3. Open the read the Wikipedia data JSON file.
    
    # 4. Read in the raw wiki movie data as a Pandas DataFrame.
    
    # 5. Return the three DataFrames
    return wiki_movies_df, kaggle_metadata, ratings

# 6 Create the path to your file directory and variables for the three files. 
file_dir = 'GoogleDrive/MyDrive/AAASchool/Class_Folder/Module_8/Movies_ETL'
# Wikipedia data
wiki_file = f'{file_dir}/wikipedia_movies.json'
# Kaggle metadata
kaggle_file = f'{file_dir}/movies_metadata.csv'
# MovieLens rating data.
ratings_file = f'{file_dir}/ratings.csv'

# 7. Set the three variables in Step 6 equal to the function created in Step 1.
wiki_file, kaggle_file, ratings_file = extract_transform_load()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /var/folders/2f/wbmj8_6510d_b_ks8ydm6mc80000gn/T/ipykernel_68090/3400731236.py in <module>
#       6
#       7 from sqlalchemy import create_engine
# ----> 8 import psycopg2
#       9
#      10 # from config import db_password
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/psycopg2/__init__.py in <module>
#      49 # Import the DBAPI-2.0 stuff into top-level module.
#      50
# ---> 51 from psycopg2._psycopg import (                     # noqa
#      52     BINARY, NUMBER, STRING, DATETIME, ROWID,
#      53
#
# ImportError: dlopen(/Users/davidlynds/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/psycopg2/_psycopg.cpython-37m-darwin.so, 0x0002): symbol not found in flat namespace '_PQbackendPID'

# %%
# 8. Set the DataFrames from the return statement equal to the file names in Step 6. 
wiki_movies_df = wiki_file
kaggle_metadata = kaggle_file
ratings = ratings_file
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/2f/wbmj8_6510d_b_ks8ydm6mc80000gn/T/ipykernel_68090/3990449309.py in <module>
#       1 # 8. Set the DataFrames from the return statement equal to the file names in Step 6.
# ----> 2 wiki_movies_df = wiki_file
#       3 kaggle_metadata = kaggle_file
#       4 ratings = ratings_file
#
# NameError: name 'wiki_file' is not defined

# %%
# 9. Check the wiki_movies_df DataFrame.
wiki_movies_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/2f/wbmj8_6510d_b_ks8ydm6mc80000gn/T/ipykernel_68090/2354353619.py in <module>
#       1 # 9. Check the wiki_movies_df DataFrame.
# ----> 2 wiki_movies_df.head()
#
# NameError: name 'wiki_movies_df' is not defined

# %%
# 10. Check the kaggle_metadata DataFrame.
kaggle_metadata.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/2f/wbmj8_6510d_b_ks8ydm6mc80000gn/T/ipykernel_68090/2119245135.py in <module>
#       1 # 10. Check the kaggle_metadata DataFrame.
# ----> 2 kaggle_metadata.head()
#
# NameError: name 'kaggle_metadata' is not defined

# %%
# 11. Check the ratings DataFrame.
ratings.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/2f/wbmj8_6510d_b_ks8ydm6mc80000gn/T/ipykernel_68090/2201363058.py in <module>
#       1 # 11. Check the ratings DataFrame.
# ----> 2 ratings.head()
#
# NameError: name 'ratings' is not defined
